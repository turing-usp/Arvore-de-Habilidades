# %%
import numpy as np
import matplotlib.pyplot
from sklearn.manifold import MDS

# %%
x = np.random.random(1000)*4 - 2
y = np.cos(x)

data = np.concatenate([x.reshape((-1,1)), y.reshape((-1,1))], axis=1)
mds = MDS(n_components=1)
new_data = mds.fit_transform(data)
